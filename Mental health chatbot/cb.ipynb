# %%
pip install streamlit faiss-cpu sentence-transformers langchain transformers pymupdf
# Out:
# ...
#      ---------------------------------------- 0.0/65.2 kB ? eta -:--:--
#      ---------------------------------------- 65.2/65.2 kB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/42.9 kB ? eta -:--:--
#      ---------------------------------------- 42.9/42.9 kB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/13.7 MB ? eta -:--:--
#    --- ------------------------------------ 1.2/13.7 MB 26.0 MB/s eta 0:00:01
#    ------- -------------------------------- 2.7/13.7 MB 28.8 MB/s eta 0:00:01
#    ------------- -------------------------- 4.7/13.7 MB 30.1 MB/s eta 0:00:01
#    ------------------- -------------------- 6.8/13.7 MB 33.4 MB/s eta 0:00:01
#    ------------------------- -------------- 8.8/13.7 MB 35.1 MB/s eta 0:00:01
#    ------------------------------- -------- 10.6/13.7 MB 36.4 MB/s eta 0:00:01
#    ------------------------------------ --- 12.3/13.7 MB 38.6 MB/s eta 0:00:01
# ...

# %%
pip install torch torchvision
# Out:
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.6 MB 7.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.9/1.6 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 9.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/204.1 MB ? eta -:--:--
#    ---------------------------------------- 0.8/204.1 MB 23.7 MB/s eta 0:00:09
#    ---------------------------------------- 1.5/204.1 MB 19.6 MB/s eta 0:00:11
#    ---------------------------------------- 2.3/204.1 MB 18.4 MB/s eta 0:00:11
#     --------------------------------------- 3.3/204.1 MB 18.9 MB/s eta 0:00:11
#     --------------------------------------- 4.3/204.1 MB 19.5 MB/s eta 0:00:11
#    - -------------------------------------- 5.4/204.1 MB 21.5 MB/s eta 0:00:10
# ...

# %%
streamlit run main.py
# Out:
#   Cell In[3], line 1
#     streamlit run main.py
#               ^
# SyntaxError: invalid syntax
